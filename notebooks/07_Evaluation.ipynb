# %% [markdown]
# # Retrieval Evaluation Metrics

# %%
eval_questions_df_FinDER= [
    {
        "question": "GM operating margin 2023 vs 2022, GM.",
        "context": [
      "CONSOLIDATED INCOME STATEMENTS\n(In millions, except per share amounts)\n \tYears Ended December 31,\n \t2023\t\t2022\t\t2021\nNet sales and revenue\t\t\t\t\t\nAutomotive\t$\t157,658 \t\t\t$\t143,975 \t\t\t$\t113,590 \t\nGM Financial\t14,184 \t\t\t12,760 \t\t\t13,414 \t\nTotal net sales and revenue (Note 3)\t171,842 \t\t\t156,735 \t\t\t127,004 \t\nCosts and expenses\t\t\t\t\t\nAutomotive and other cost of sales\t141,330 \t\t\t126,892 \t\t\t100,544 \t\nGM Financial interest, operating and other expenses\t11,374 \t\t\t8,862 \t\t\t8,582 \t\nAutomotive and other selling, general and administrative expense\t9,840 \t\t\t10,667 \t\t\t8,554 \t\nTotal costs and expenses\t162,544 \t\t\t146,421 \t\t\t117,680 \t\nOperating income (loss)\t9,298 \t\t\t10,315 \t\t\t9,324 \t\nAutomotive interest expense\t911 \t\t\t987 \t\t\t950 \t\nInterest income and other non-operating income, net (Note 19)\t1,537 \t\t\t1,432 \t\t\t3,041 \t\nEquity income (loss) (Note 8)\t480 \t\t\t837 \t\t\t1,301 \t\nIncome (loss) before income taxes\t10,403 \t\t\t11,597 \t\t\t12,716 \t\nIncome tax expense (benefit) (Note 17)\t563 \t\t\t1,888 \t\t\t2,771 \t\nNet income (loss)\t9,840 \t\t\t9,708 \t\t\t9,945 \t\nNet loss (income) attributable to noncontrolling interests\t287 \t\t\t226 \t\t\t74 \t\nNet income (loss) attributable to stockholders\t$\t10,127 \t\t\t$\t9,934 \t\t\t$\t10,019 \t\nNet income (loss) attributable to common stockholders\t$\t10,022 \t\t\t$\t8,915 \t\t\t$\t9,837 \t\nEarnings per share (Note 21)\t\t\t\t\t\nBasic earnings per common share\t$\t7.35 \t\t\t$\t6.17 \t\t\t$\t6.78 \t\nWeighted-average common shares outstanding \u2013 basic\t1,364 \t\t\t1,445 \t\t\t1,451 \t\nDiluted earnings per common share\t$\t7.32 \t\t\t$\t6.13 \t\t\t$\t6.70 \t\nWeighted-average common shares outstanding \u2013 diluted\t1,369 \t\t\t1,454 \t\t\t1,468"
        ],
        "source": "FinDER",
        "id": "182f0809"
    },
    {
        "question": "NGC's cyber investments boost investor confidence, enhance valuation, and bolster stability.",
        "context": [
        "We recognize the critical importance of maintaining the safety and security of our systems and data and have a holistic process for overseeing and managing cybersecurity and related risks. This process is supported by both management and our Board of Directors.\nThe Chief Information Office, which maintains our cybersecurity function, is led by our Chief Information Officer (CIO), who reports to our CEO. The Chief Information Security Officer (CISO) reports to the CIO and generally is responsible for management of cybersecurity risk and the protection and defense of our networks and systems. The CISO manages a team of cybersecurity professionals with broad experience and expertise, including in cybersecurity threat assessments and detection, mitigation technologies, cybersecurity training, incident response, cyber forensics, insider threats and regulatory compliance.\nOur Board of Directors is responsible for overseeing our enterprise risk management activities in general, and each of our Board committees assists the Board in the role of risk oversight. The full Board receives an update on the Company\u2019s risk management process and the risk trends related to cybersecurity at least annually. The Audit and Risk Committee specifically assists the Board in its oversight of risks related to cybersecurity. To help ensure effective oversight, the Audit and Risk Committee receives reports on information security and cybersecurity from the CISO at least four times a year.\nIn addition, the Company\u2019s Enterprise Risk Management Council (ERMC) considers risks relating to cybersecurity, among other significant risks, and applicable mitigation plans to address such risks. The ERMC is comprised of the Executive Leadership Team, as well as the Chief Accounting Officer, Chief Compliance Officer, Corporate Secretary, Chief Sustainability Officer, Treasurer and Vice President, Internal Audit. The CIO and CISO attend each ERMC meeting. The ERMC meets during the year and receives periodic updates on cybersecurity risks from the CIO and CISO. We have an established process and playbook led by our CISO governing our assessment, response and notifications internally and externally upon the occurrence of a cybersecurity incident. Depending on the nature and severity of an incident, this process provides for escalating notification to our CEO and the Board (including our Lead Independent Director and the Audit and Risk Committee chair).\nOur approach to cybersecurity risk management includes the following key elements:\n\u2022Multi-Layered Defense and Continuous Monitoring \u2013 We work to protect our computing environments and products from cybersecurity threats through multi-layered defenses and apply lessons learned from our defense and monitoring efforts to help prevent future attacks. We utilize data analytics to detect anomalies and search for cyber threats. Our Cybersecurity Operations Center provides comprehensive cyber threat detection and response capabilities and maintains a 24x7 monitoring system which complements the technology, processes and threat detection techniques we use to monitor, manage and mitigate cybersecurity threats. From time to time, we engage third party consultants or other advisors to assist in assessing, identifying and\/or managing cybersecurity threats. We also periodically use our Internal Audit function to conduct additional reviews and assessments.\n\u2022Insider Threats \u2013 We maintain an insider threat program designed to identify, assess, and address potential risks from within our Company. Our program evaluates potential risks consistent with industry practices, customer requirements and applicable law, including privacy and other considerations.\n\u2022Information Sharing and Collaboration \u2013 We work with government, customer, industry and\/or supplier partners, such as the National Defense Information Sharing and Analysis Center and other government-industry partnerships, to gather and develop best practices and share information to address cyber threats. These relationships enable the rapid sharing of threat and vulnerability mitigation information across the defense industrial base and supply chain.\n\u2022Third Party Risk Assessments \u2013 We conduct information security assessments before sharing or allowing the hosting of sensitive data in computing environments managed by third parties, and our standard terms and conditions contain contractual provisions requiring certain security protections.\n\u2022Training and Awareness \u2013 We provide awareness training to our employees to help identify, avoid and mitigate cybersecurity threats. Our employees with network access participate annually in required training, including spear phishing and other awareness training. We also periodically host tabletop exercises with management and other employees to practice rapid cyber incident response.\n\u2022Supplier Engagement \u2013 We provide training and other resources to our suppliers to support cybersecurity resiliency in our supply chain. We also require our suppliers to comply with our standard information security terms and conditions, in addition to any requirements from our customers, as a condition of doing business with us, and require them to complete information security questionnaires to review and assess any potential cyber-related risks depending on the nature of the services being provided.\nWhile we have experienced cybersecurity incidents in the past, to date none have materially affected the Company or our financial position, results of operations and\/or cash flows. We continue to invest in the cybersecurity and resiliency of our networks and to enhance our internal controls and processes, which are designed to help protect our systems and infrastructure, and the information they contain. For more information regarding the risks we face from cybersecurity threats, please see \u201cRisk Factors.\u201d\nFORWARD-LOOKING STATEMENTS AND PROJECTIONS\nThis Annual Report on Form 10-K and the information we are incorporating by reference contain statements that constitute \u201cforward-looking statements\u201d within the meaning of the Private Securities Litigation Reform Act of 1995. Words such as \u201cwill,\u201d \u201cexpect,\u201d \u201canticipate,\u201d \u201cintend,\u201d \u201cmay,\u201d \u201ccould,\u201d \u201cshould,\u201d \u201cplan,\u201d \u201cproject,\u201d \u201cforecast,\u201d \u201cbelieve,\u201d \u201cestimate,\u201d \u201cguidance,\u201d \u201coutlook,\u201d \u201ctrends,\u201d \u201cgoals\u201d and similar expressions generally identify these forward-looking statements. Forward-looking statements include, among other things, statements relating to our future financial condition, results of operations and\/or cash flows. Forward-looking statements are based upon assumptions, expectations, plans and projections that we believe to be reasonable when made, but which may change over time. These statements are not guarantees of future performance and inherently involve a wide range of risks and uncertainties that are difficult to predict. Specific risks that could cause actual results to differ materially from those expressed or implied in these forward-looking statements include, but are not limited to, those identified under \u201cRisk Factors\u201d and other important factors disclosed in this report and from time to time in our other SEC filings. These risks and uncertainties are amplified by the global macroeconomic, security and political environments, including inflationary pressures, labor and supply chain challenges, which have caused and will continue to cause significant challenges, instability and uncertainty. They include:\nIndustry and Economic Risks\n\u2022our dependence on the U.S. government for a substantial portion of our business\n\u2022significant delays or reductions in appropriations and\/or for our programs, and U.S. government funding and program support more broadly, including as a result of a prolonged continuing resolution and\/or government shutdown, and\/or related to the global security environment or other global events\n\u2022significant delays or reductions in payments as a result of or related to a breach of the debt ceiling\n\u2022the use of estimates when accounting for our contracts and the effect of contract cost growth and our efforts to recover or offset such costs and\/or changes in estimated contract costs and revenues, including as a result of inflationary pressures, labor shortages, supply chain challenges and\/or other macroeconomic factors, and risks related to management\u2019s judgments and assumptions in estimating and\/or projecting contract revenue and performance which may be inaccurate\n\u2022continued pressures from macroeconomic trends, including on costs, schedules, performance and ability to meet expectations\n\u2022increased competition within our markets and bid protests\nLegal and Regulatory Risks\n\u2022investigations, claims, disputes, enforcement actions, litigation (including criminal, civil and administrative) and\/or other legal proceedings\n\u2022the improper conduct of employees, agents, subcontractors, suppliers, business partners or joint ventures in which we participate, including the impact on our reputation and our ability to do business\n\u2022changes in procurement and other laws, SEC, DoD and other rules and regulations, contract terms and practices applicable to our industry, findings by the U.S. government as to our compliance with such requirements, more aggressive enforcement of such requirements and changes in our customers\u2019 business practices globally\n\u2022environmental matters, including climate change, unforeseen environmental costs and government and third party claims\n\u2022unanticipated changes in our tax provisions or exposure to additional tax liabilities\nBusiness and Operational Risks\n\u2022cyber and other security threats or disruptions faced by us, our customers or our suppliers and other partners, and changes in related regulations\n\u2022our ability to attract and retain a qualified, talented and diverse workforce with the necessary security clearances to meet our performance obligations\n\u2022the performance and viability of our subcontractors and suppliers and the availability and pricing of raw materials and components, particularly with inflationary pressures, increased costs, shortages in labor and financial resources, supply chain disruptions, and extended material lead times\n\u2022impacts related to health epidemics and pandemics and similar outbreaks\n\u2022our exposure to additional risks as a result of our international business, including risks related to global security, geopolitical and economic factors, misconduct, suppliers, laws and regulations\n\u2022our ability to innovate, develop new products and technologies, progress and benefit from digital transformation and maintain technologies to meet the needs of our customers\n\u2022natural disasters\n\u2022products and services we provide related to hazardous and high risk operations, including the production and use of such products, which subject us to various environmental, regulatory, financial, reputational and other risks\n\u2022our ability appropriately to exploit and\/or protect intellectual property rights\nGeneral and Other Risk Factors\n\u2022the adequacy and availability of, and ability to obtain, insurance coverage, customer indemnifications or other liability protections\n\u2022the future investment performance of plan assets, gains or losses associated with changes in valuation of marketable securities related to our non-qualified benefit plans, changes in actuarial assumptions associated\nwith our pension and other postretirement benefit plans and legislative or other regulatory actions impacting our pension and postretirement benefit obligations\n\u2022changes in business conditions that could impact business investments and\/or recorded goodwill or the value of other long-lived assets, and other potential future liabilities\nWe urge you to consider the limitations on, and risks associated with, forward-looking statements and not unduly rely on the accuracy of forward-looking statements. These forward-looking statements speak only as of the date this report is first filed or, in the case of any document incorporated by reference, the date of that document. We undertake no obligation to publicly update or revise any forward-looking statements, whether as a result of new information, future events or otherwise, except as required by applicable law."
        ],
        "source": "FinDER",
        "id": "c593f878"
    },
    {
        "question": "SBA Comm., credit evals & DTA quality receivables.",
        "context": [
      "Site leasing revenues\n\nRevenue from site leasing is recognized on a straight-line basis over the current term of the related lease agreements, which are generally five years to fifteen years. Receivables recorded related to the straight-lining of site leases are reflected in other assets on the Consolidated Balance Sheets. Rental amounts received in advance are recorded as deferred revenue on the Consolidated Balance Sheets. Revenue from site leasing represents 93% of our total revenue for the year ended December 31, 2023. \n\nSite development revenues\n\nSite development projects in which we perform consulting services include contracts on a fixed price basis that are billed at contractual rates. Revenue is recognized over time based on milestones achieved, which are determined based on costs incurred. Amounts billed in advance (collected or uncollected) are recorded as deferred revenue on our Consolidated Balance Sheets.\n\nRevenue from construction projects is recognized over time, determined by the percentage of cost incurred to date compared to management\u2019s estimated total cost for each contract. This method is used because management considers total cost to be the best available measure of progress on the contracts. These amounts are based on estimates, and the uncertainty inherent in the estimates initially is reduced as work on the contracts nears completion. Refer to Note 5 in our Consolidated Financial Statements included in this annual report for further detail of costs and estimated earnings in excess of billings on uncompleted contracts. Provisions for estimated losses on uncompleted contracts are made in the period in which such losses are determined to be probable.\n\nThe site development segment represents approximately 7% of our total revenues for the year ended December 31, 2023. We account for site development revenue in accordance with ASC 606, Revenue from Contracts with Customers. Payment terms do not result in any significant financing arrangements. Furthermore, these contracts do not typically include variable consideration; therefore, the transaction price that is recognized over time is generally the amount of the total contract.\n\nAccounts receivable\n\nThe accounts receivable balance for the years ended December 31, 2023 and 2022 was $182.7 million and $184.4 million, respectively, of which $32.3 million and $59.6 million related to the site development segment, respectively. We perform periodic credit evaluations of our customers. In addition, we monitor collections and payments from our customers and maintain a provision for estimated credit losses based upon historical experience, specific customer collection issues identified, and past due balances as determined based on contractual terms. Interest is charged on outstanding receivables from customers on a case by case basis in accordance with the terms of the respective contracts or agreements with those customers. Amounts determined to be uncollectible are written off against the allowance for doubtful accounts in the period in which uncollectibility is determined to be probable. Refer to Note 15 in our Consolidated Financial Statements included in this annual report for further detail of the site development segment."
        ],
        "source": "FinDER",
        "id": "cb08b8b0"
    },
    {
        "question": "R&D expense as a % of net product revs for VRTX in 2023.",
        "context": [
      "VERTEX PHARMACEUTICALS INCORPORATED\nConsolidated Statements of Income\n(in millions, except per share amounts)\nYear Ended December 31,\n2023\t\t2022\t\t2021\nRevenues:\t\t\t\t\t\nProduct revenues, net\t$\t9,869.2 \t\t\t$\t8,930.7 \t\t\t$\t7,573.4 \t\nOther revenues\n\u2014 \t\t\t\u2014 \t\t\t1.0 \t\nTotal revenues\t9,869.2 \t\t\t8,930.7 \t\t\t7,574.4 \t\nCosts and expenses:\t\t\t\t\t\nCost of sales\t1,262.2 \t\t\t1,080.3 \t\t\t904.2 \t\nResearch and development expenses\t3,162.9 \t\t\t2,540.3 \t\t\t1,937.8 \t\nAcquired in-process research and development expenses\t527.1 \t\t\t115.5 \t\t\t1,113.3 \t\nSelling, general and administrative expenses\t1,136.6 \t\t\t944.7 \t\t\t840.1 \t\nChange in fair value of contingent consideration\t(51.6)\t\t\t(57.5)\t\t\t(3.1)\t\nTotal costs and expenses\n6,037.2 \t\t\t4,623.3 \t\t\t4,792.3 \t\nIncome from operations\t3,832.0 \t\t\t4,307.4 \t\t\t2,782.1 \t\nInterest income\t614.7 \t\t\t144.6 \t\t\t4.9 \t\nInterest expense\t(44.1)\t\t\t(54.8)\t\t\t(61.5)\t\nOther (expense) income, net\t(22.8)\t\t\t(164.8)\t\t\t4.9 \t\nIncome before provision for income taxes\t4,379.8 \t\t\t4,232.4 \t\t\t2,730.4 \t\nProvision for income taxes\t760.2 \t\t\t910.4 \t\t\t388.3 \t\nNet income\n$\t3,619.6 \t\t\t$\t3,322.0 \t\t\t$\t2,342.1 \t\nNet income per common share:\t\t\t\t\t\nBasic\n$\t14.05 \t\t\t$\t12.97 \t\t\t$\t9.09 \t\nDiluted\n$\t13.89 \t\t\t$\t12.82 \t\t\t$\t9.01 \t\nShares used in per share calculations:\t\t\t\t\t\nBasic\n257.7 \t\t\t256.1 \t\t\t257.7 \t\nDiluted\n260.5 \t\t\t259.1 \t\t\t259.9"
        ],
        "source": "FinDER",
        "id": "89747a6d"
    },
    {
        "question": "% of part-time workforce and flexibility in labor costs for SPG.",
        "context": [
      "At December 31, 2023, we and our affiliates employed approximately 3,000 persons at various properties and offices throughout the United States, of which approximately 500 were part-time. Approximately 1,000 of these employees were located at our corporate headquarters in Indianapolis, Indiana."
        ],
        "source": "FinDER",
        "id": "366d49d1"
    }

]

# %%
eval_questions_df_others= [
{"id" : "STT\/2006\/page_96.pdf", "question" : "For STT, what is the growth rate in the risk-free interest rate from 2004 to 2005?", "source": "FinQA", "reference_contexts": ["\n\t2006\t2005\t2004\ndividend yield\t1.41% ( 1.41 % )\t1.85% ( 1.85 % )\t1.35% ( 1.35 % )\nexpected volatility\t26.50\t28.70\t27.10\nrisk-free interest rate\t4.60\t4.19\t3.02\nexpected option lives ( in years )\t7.8\t7.8\t5.0\n['compensation expense related to stock options , stock appreciation rights , restricted stock awards , deferred stock awards and performance awards , which we record as a component of salaries and employee benefits expense in our consolidated statement of income , was $ 208 million , $ 110 million and $ 74 million for the years ended december 31 , 2006 , 2005 and 2004 , respectively .', 'the related total income tax benefit recorded in our consolidated statement of income was $ 83 million , $ 44 million and $ 30 million for 2006 , 2005 and 2004 , respectively .', 'seq 87 copyarea : 38 .', 'x 54 .', 'trimsize : 8.25 x 10.75 typeset state street corporation serverprocess c:\\\\\\\\fc\\\\\\\\delivery_1024177\\\\\\\\2771-1-do_p.pdf chksum : 0 cycle 1merrill corporation 07-2771-1 thu mar 01 17:11:13 2007 ( v 2.247w--stp1pae18 ) .']"] },
{"id" : "STT\/2011\/page_94.pdf", "question" : "For STT, what was the percent change in the value of commercial paper outstanding between 2010 and 2011?", "source": "FinQA", "reference_contexts": ["we maintain an effective universal shelf registration that allows for the public offering and sale of debt securities , capital securities , common stock , depositary shares and preferred stock , and warrants to purchase such securities , including any shares into which the preferred stock and depositary shares may be convertible , or any combination thereof .", "at december 31 , 2011 , we had $ 2.38 billion of commercial paper outstanding , compared to $ 2.80 billion at december 31 , 2010 ."] },
{"id" : "RSG\/2008\/page_114.pdf", "question" : "For RSG, what was the percent of the growth in the revenues from 2007 to 2008?", "source": "FinQA", "reference_contexts": ["\n\tyear ended december 31 2008 ( unaudited )\tyear ended december 31 2007 ( unaudited )\nrevenue\t$ 9362.2\t$ 9244.9\nincome from continuing operations available to common stockholders\t285.7\t423.2\nbasic earnings per share\t.76\t1.10\ndiluted earnings per share\t.75\t1.09\n['the above unaudited pro forma financial information includes adjustments for amortization of identifiable intangible assets , accretion of discounts to fair value associated with debt , environmental , self-insurance and other liabilities , accretion of capping , closure and post-closure obligations and amortization of the related assets , and provision for income taxes .', 'assets held for sale as a condition of the merger with allied in december 2008 , we reached a settlement with the doj requiring us to divest of certain operations serving fifteen metropolitan areas including los angeles , ca ; san francisco , ca ; denver , co ; atlanta , ga ; northwestern indiana ; lexington , ky ; flint , mi ; cape girardeau , mo ; charlotte , nc ; cleveland , oh ; philadelphia , pa ; greenville-spartanburg , sc ; and fort worth , houston and lubbock , tx .', 'the settlement requires us to divest 87 commercial waste collection routes , nine landfills and ten transfer stations , together with ancillary assets and , in three cases , access to landfill disposal capacity .', 'we have classified the assets and liabilities we expect to divest ( including accounts receivable , property and equipment , goodwill , and accrued landfill and environmental costs ) as assets held for sale in our consolidated balance sheet at december 31 , 2008 .', 'the assets held for sale related to operations that were republic 2019s prior to the merger with allied have been adjusted to the lower of their carrying amounts or estimated fair values less costs to sell , which resulted in us recognizing an asset impairment loss of $ 6.1 million in our consolidated statement of income for the year ended december 31 , 2008 .', 'the assets held for sale related to operations that were allied 2019s prior to the merger are recorded at their estimated fair values in our consolidated balance sheet as of december 31 , 2008 in accordance with the purchase method of accounting .', 'in february 2009 , we entered into an agreement to divest certain assets to waste connections , inc .', 'the assets covered by the agreement include six municipal solid waste landfills , six collection operations and three transfer stations across the following seven markets : los angeles , ca ; denver , co ; houston , tx ; lubbock , tx ; greenville-spartanburg , sc ; charlotte , nc ; and flint , mi .', 'the transaction with waste connections is subject to closing conditions regarding due diligence , regulatory approval and other customary matters .', 'closing is expected to occur in the second quarter of 2009 .', 'republic services , inc .', 'and subsidiaries notes to consolidated financial statements %%transmsg*** transmitting job : p14076 pcn : 106000000 ***%%pcmsg|104 |00046|yes|no|02\/28\/2009 21:07|0|0|page is valid , no graphics -- color : d| .'"] },
{"id" : "C\/2009\/page_53.pdf", "question" : "For Citi, what was the change in tier 1 capital ratio between 2008 and 2009?", "source": "FinQA", "reference_contexts": ["\nat year end\t2009\t2008\ntier 1 common\t9.60% ( 9.60 % )\t2.30% ( 2.30 % )\ntier 1 capital\t11.67\t11.92\ntotal capital ( tier 1 capital and tier 2 capital )\t15.25\t15.70\nleverage\t6.89\t6.08\n['as noted in the table above , citigroup was 201cwell capitalized 201d under the federal bank regulatory agency definitions at year end for both 2009 and 2008. .'"] },
{"id" : "UPS\/2013\/page_34.pdf", "question" : "Q: what was the value of united parcel service inc . in the year of 2013?\nA: 221.91\nQ: and what is the difference between that value and the original investment made in 2008?\nA: A0\nQ: how much does that difference represent, in percentage, in relation to the original investment?\nA: A1\nQ: what is the difference between the value of dow jones transportation average in 2013 and 2008?", "source": "ConvFinQA", "reference_contexts": ["nunited parcel service inc .\t$ 100.00\t$ 107.75\t$ 140.39\t$ 145.84\t$ 151.44\t$ 221.91\nstandard & poor 2019s 500 index\t$ 100.00\t$ 126.45\t$ 145.49\t$ 148.55\t$ 172.30\t$ 228.09\ndow jones transportation average\t$ 100.00\t$ 118.59\t$ 150.30\t$ 150.31\t$ 161.56\t$ 228.42\n"] },
]

# %% [markdown]
# **Retrieval for only FinQA and ConFinQA**

# %%
from tqdm import tqdm
import pandas as pd
# Now import your function
import sys
import os
from dotenv import load_dotenv

# Adjust path to include the module directory (if needed)
#sys.path.append("/Users/christel/Desktop/Thesis/thesis_repo/src/retrievers/graphrag")
#/Users/christel/Desktop/Thesis/thesis_repo/src/retrievers/graphrag/graphRAG_retriever.py
# Add the full path to the parent "src" folder
sys.path.append("/Users/christel/Desktop/Thesis/thesis_repo")

# Load environment variables
load_dotenv()
from src.retrievers.graphrag.graphRAG_retriever import retrieve
# Ensure your .env is loaded (if not already)

retrieval_dataset = []

# Loop through each question
for item in tqdm(eval_questions_df_others):
    question_id = item["id"]
    question_text = item["question"]
    source = item.get("source", "")  # optional if you need it later
    reference_contexts = item.get("reference_contexts", [])  # optional if you need it later

    try:
        result = retrieve(question_text)
    except Exception as e:
        print(f"❌ Failed to retrieve for {question_id}: {e}")
        continue

    retrieved_chunks = [r["text"] for r in result.get("candidates", [])]

    # Append in format expected by context_recall_with_reference
    retrieval_dataset.append({
        "question_id": question_id,
        "user_input": question_text,
        "retrieved_contexts": retrieved_chunks,
        "reference_contexts": reference_contexts,   
        "source": source  # optional metadata
    })

# Optional: store in DataFrame for inspection
retrieval_df_others = pd.DataFrame(retrieval_dataset)
# Out:
# /Users/christel/Desktop/Thesis/thesis_repo/graph-env/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# 100%|██████████| 5/5 [00:14<00:00,  3.00s/it]

# %%
retrieval_df_others.head()
# Out:
#                question_id                                         user_input  \
# 0   STT\/2006\/page_96.pdf  For STT, what is the growth rate in the risk-f...
# 1   STT\/2011\/page_94.pdf  For STT, what was the percent change in the va...
# 2  RSG\/2008\/page_114.pdf  For RSG, what was the percent of the growth in...
# 3     C\/2009\/page_53.pdf  For Citi, what was the change in tier 1 capita...
# 4   UPS\/2013\/page_34.pdf  Q: what was the value of united parcel service...
#
#                                   retrieved_contexts  \
# 0  [['management believes it is important for int...
# 1  [['we maintain an effective universal shelf re...
# 2  [Total Company Revenue. The increase in organi...
# 3  [['capital resources and liquidity capital res...
# 4  [['shareowner return performance graph the fol...
#
#                                   reference_contexts     source
# 0  [\n\t2006\t2005\t2004\ndividend yield\t1.41% (...      FinQA
# ...

# %%
# Method 1: View a specific row by index (e.g., row 0)
row_index = 3
sample = retrieval_df_others.iloc[row_index]

print(f"=== EXAMPLE {row_index} ===")
print(f"Question ID: {sample['question_id']}")
print(f"Question: {sample['user_input']}")
print(f"Source: {sample['source']}")

print(f"\n=== REFERENCE CONTEXTS ===")
for i, ref_ctx in enumerate(sample['reference_contexts']):
    print(f"Reference {i+1}:")
    print(ref_ctx)
    print("-" * 50)

print(f"\n=== RETRIEVED CONTEXTS ===")
for i, ret_ctx in enumerate(sample['retrieved_contexts']):
    print(f"Retrieved {i+1}:")
    print(ret_ctx)
    print("-" * 50)
# Out:
# === EXAMPLE 3 ===
# Question ID: C\/2009\/page_53.pdf
# Question: For Citi, what was the change in tier 1 capital ratio between 2008 and 2009?
# Source: FinQA
#
# === REFERENCE CONTEXTS ===
# Reference 1:
#
# at year end	2009	2008
# tier 1 common	9.60% ( 9.60 % )	2.30% ( 2.30 % )
# tier 1 capital	11.67	11.92
# total capital ( tier 1 capital and tier 2 capital )	15.25	15.70
# leverage	6.89	6.08
# ['as noted in the table above , citigroup was 201cwell capitalized 201d under the federal bank regulatory agency definitions at year end for both 2009 and 2008. .'
# --------------------------------------------------
#
# === RETRIEVED CONTEXTS ===
# Retrieved 1:
# ...

# %% [markdown]
# **Retrieval for FinDER**

# %%
from tqdm import tqdm
import pandas as pd
# Now import your function
import sys
import os
from dotenv import load_dotenv

# Adjust path to include the module directory (if needed)
#sys.path.append("/Users/christel/Desktop/Thesis/thesis_repo/src/retrievers/graphrag")
#/Users/christel/Desktop/Thesis/thesis_repo/src/retrievers/graphrag/graphRAG_retriever.py
# Add the full path to the parent "src" folder
sys.path.append("/Users/christel/Desktop/Thesis/thesis_repo")

# Load environment variables
load_dotenv()
from src.retrievers.graphrag.graphRAG_retriever import retrieve
# Ensure your .env is loaded (if not already)

retrieval_dataset = []

# Loop through each question
for item in tqdm(eval_questions_df_FinDER):
    question_id = item["id"]
    question_text = item["question"]
    source = item.get("source", "")  # optional if you need it later
    reference_contexts = item.get("context", [])  # optional if you need it later

    try:
        result = retrieve(question_text)
    except Exception as e:
        print(f"❌ Failed to retrieve for {question_id}: {e}")
        continue

    retrieved_chunks = [r["text"] for r in result.get("candidates", [])]

    # Append in format expected by context_recall_with_reference
    retrieval_dataset.append({
        "question_id": question_id,
        "user_input": question_text,
        "retrieved_contexts": retrieved_chunks,
        "reference_contexts": reference_contexts,   
        "source": source  # optional metadata
    })

# Optional: store in DataFrame for inspection
retrieval_df_FinDER = pd.DataFrame(retrieval_dataset)
# Out:
# 100%|██████████| 5/5 [00:14<00:00,  2.92s/it]

# %%
retrieval_df_FinDER.head()
# Out:
#   question_id                                         user_input  \
# 0    182f0809              GM operating margin 2023 vs 2022, GM.
# 1    c593f878  NGC's cyber investments boost investor confide...
# 2    cb08b8b0  SBA Comm., credit evals & DTA quality receivab...
# 3    89747a6d  R&D expense as a % of net product revs for VRT...
# 4    366d49d1  % of part-time workforce and flexibility in la...
#
#                                   retrieved_contexts  \
# 0  [Risk Management and Strategy\n\nMaterial risk...
# 1  [Financial Stability\n\nIn addition to our sus...
# 2  [Exploring Opportunities in Evolving Technolog...
# 3  [['table of contents research and development ...
# 4  [As of December 31, 2023, we had 1,681 active,...
#
#                                   reference_contexts  source
# 0  [CONSOLIDATED INCOME STATEMENTS\n(In millions,...  FinDER
# 1  [We recognize the critical importance of maint...  FinDER
# 2  [Site leasing revenues\n\nRevenue from site le...  FinDER
# ...

# %% [markdown]
# ## Retrieval Evaluation Metric For FinQA and ConvFinQA

# %% [markdown]
# ### String Presence with Reference
# Calculates the per-gold context recall. Output shows what fraction of the gold/reference contexts that was matched by at least one of the retrieved results.

# %%
from typing import List, Dict, Tuple, Iterable, Optional
import re
import numpy as np
import pandas as pd
from tqdm import tqdm
from math import log2

# %% [markdown]
# Helper functions:

# %%
def normalize_text(s: str) -> str:
    if not isinstance(s, str):
        return ""
    s = s.lower().strip()
    # collapse whitespace and common artifacts
    s = s.replace("\t", " ")
    s = s.replace("\n", " ")
    s = " ".join(s.split())
    return s

NUM_RE = re.compile(r"(?<![\w.])(?:\d{1,3}(?:,\d{3})*|\d+)(?:\.\d+)?%?")


def extract_numbers(text: str) -> list[str]:
    out = []
    for m in NUM_RE.findall(text or ""):
        out.append(m.replace(",", ""))  # keep % if present
    return out

def as_float_safe(s: str) -> Optional[float]:
    try:
        return float(s.rstrip("%")) if s.endswith("%") else float(s)
    except Exception:
        return None
    

def numbers_coverage(
    gold_nums: list[str],
    retr_nums: list[str],
    *,
    tol: float = 0.0,
    min_unique_hits: int = 4,
    min_coverage: float = 0.8,
) -> bool:
    """
    Returns True if the retrieved numerics cover the gold numerics well enough.
    - tol: absolute tolerance (e.g., 0.01)
    - min_unique_hits: at least this many distinct numeric values must match
    - min_coverage: matched / len(unique gold nums) threshold
    Matching is done by exact string OR numeric within tolerance.
    """
    if not gold_nums or not retr_nums:
        return False

    # dedupe to avoid inflated coverage from repeated values
    gold_unique = list(dict.fromkeys(gold_nums))
    retr_unique = list(dict.fromkeys(retr_nums))

    retr_set = set(retr_unique)  # fast string matches
    retr_floats = [as_float_safe(x) for x in retr_unique]
    retr_floats = [x for x in retr_floats if x is not None]

    hits = 0
    matched_values = set()

    for g in gold_unique:
        if g in retr_set:
            hits += 1
            matched_values.add(g)
            continue
        # try numeric tolerance
        gf = as_float_safe(g)
        if gf is None or tol <= 0 or not retr_floats:
            continue
        # any retrieved within tolerance counts
        for rf in retr_floats:
            if abs(gf - rf) <= tol:
                hits += 1
                matched_values.add(g)
                break

    coverage = hits / max(len(gold_unique), 1)
    return hits >= min_unique_hits and coverage >= min_coverage

def is_table_like(
    text: str,
    *,
    min_numbers: int = 8,
    min_num_density: float = 0.15,
) -> bool:
    """
    Heuristic: treat as table-like if it has lots of numbers and num-density is high.
    """
    if not text:
        return False
    nums = extract_numbers(text)
    if len(nums) < min_numbers:
        return False

    # crude density: numeric tokens / total tokens
    toks = re.findall(r"\S+", text)
    density = (len(nums) / max(len(toks), 1))
    return density >= min_num_density

def exact_or_table_numeric_match(
    gold: str,
    retrieved: str,
    *,
    use_table_numeric: bool,
    table_tol: float = 0.0,
    min_unique_hits: int = 4,
    min_coverage: float = 0.8,
) -> bool:
    """
    First try exact containment; if that fails and use_table_numeric=True,
    compare numeric coverage.
    """
    g = normalize_text(gold)
    r = normalize_text(retrieved)

    # exact containment (cheap & strict)
    if g and r and (g in r or r in g):
        return True

    if not use_table_numeric:
        return False

    g_nums = extract_numbers(gold)
    r_nums = extract_numbers(retrieved)
    return numbers_coverage(
        g_nums, r_nums,
        tol=table_tol,
        min_unique_hits=min_unique_hits,
        min_coverage=min_coverage,
    )

# %%
def string_presence_with_reference(
    dataset: List[Dict],
    top_k_context_key: str = "retrieved_contexts",
    gold_context_key: str = "reference_contexts",
    k: int = 10,
    # table matching controls
    detect_tables: "auto|bool" = "auto",     # "auto" (heuristic), True (force), or False (disable)
    table_tol: float = 0.0,                  # numeric tolerance for tables (e.g., 0.01)
    min_unique_hits: int = 4,
    min_coverage: float = 0.8,
    # optional per-sample override key: sample["is_table_reference"] = True/False
    table_flag_key: str = "is_table_reference",
    verbose: bool = False,
) -> Tuple[pd.DataFrame, pd.DataFrame]:
    """
    Exact-only evaluator with a numeric fallback for table-like references.

    - Per retrieved item, we mark relevant if:
        exact containment  OR  (reference is table-like AND numeric coverage passes)
    - Per gold recall uses the same logic.
    - You can force table behavior globally with detect_tables=True,
      disable with False, or auto-detect with "auto".
    - You can override per sample by setting sample[table_flag_key] = True/False.
    """
    recall_rows = []
    debug_rows = []

    for sample in tqdm(dataset):
        question = sample.get("user_input", "N/A")
        retrieved_raw = (sample.get(top_k_context_key, []) or [])[:k]
        gold_raw = sample.get(gold_context_key, []) or []

        retrieved_norm = [normalize_text(r) for r in retrieved_raw if isinstance(r, str)]
        gold_norm = [normalize_text(g) for g in gold_raw if isinstance(g, str)]

        # decide table-ness for this sample (per gold string)
        per_gold_is_table = []
        for g_raw in gold_raw:
            # per-sample override wins if present
            if table_flag_key in sample:
                is_tbl = bool(sample[table_flag_key])
            else:
                if detect_tables is True:
                    is_tbl = True
                elif detect_tables is False:
                    is_tbl = False
                else:  # "auto"
                    is_tbl = is_table_like(g_raw)
            per_gold_is_table.append(is_tbl)

        # per-retrieved flags (True if any gold deems it relevant)
        retrieved_hit_exact = []
        for r_raw in retrieved_raw:
            hit = False
            for g_raw, is_tbl in zip(gold_raw, per_gold_is_table):
                if exact_or_table_numeric_match(
                    g_raw, r_raw,
                    use_table_numeric=is_tbl,
                    table_tol=table_tol,
                    min_unique_hits=min_unique_hits,
                    min_coverage=min_coverage,
                ):
                    hit = True
                    break
            retrieved_hit_exact.append(hit)

        # per-gold recall + missing lists
        total = len(gold_norm)
        em_hits_gold = 0
        missing_em = []
        for g_raw, is_tbl in zip(gold_raw, per_gold_is_table):
            ok = any(
                exact_or_table_numeric_match(
                    g_raw, r_raw,
                    use_table_numeric=is_tbl,
                    table_tol=table_tol,
                    min_unique_hits=min_unique_hits,
                    min_coverage=min_coverage,
                )
                for r_raw in retrieved_raw
            )
            if ok:
                em_hits_gold += 1
            else:
                missing_em.append(normalize_text(g_raw))

        recall_em = em_hits_gold / total if total else 0.0

        recall_rows.append({
            "question": question,
            "total_gold": total,
            "retrieved_k": len(retrieved_norm),
            "recall_em": recall_em,
            "missing_em": missing_em,
        })

        debug_rows.append({
            "question": question,
            "retrieved_norm": retrieved_norm,
            "reference_norm": gold_norm,
            "retrieved_hit_exact": retrieved_hit_exact,  # used for nDCG
            "gold_table_like": per_gold_is_table,
        })

    recall_df = pd.DataFrame(recall_rows)
    debug_df = pd.DataFrame(debug_rows)
    return recall_df, debug_df

# %%
recall_df_others, debug_df_others = string_presence_with_reference(
    dataset=retrieval_df_others.to_dict(orient="records"),
    top_k_context_key="retrieved_contexts",
    gold_context_key="reference_contexts",
    k=10
)
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 285.65it/s]

# %%
recall_df_others.head()
# Out:
#                                             question  total_gold  retrieved_k  \
# 0  For STT, what is the growth rate in the risk-f...           1           10
# 1  For STT, what was the percent change in the va...           2           10
# 2  For RSG, what was the percent of the growth in...           1           10
# 3  For Citi, what was the change in tier 1 capita...           1           10
# 4  Q: what was the value of united parcel service...           1           10
#
#    recall_em                                         missing_em
# 0        1.0                                                 []
# 1        1.0                                                 []
# 2        0.0  [year ended december 31 2008 ( unaudited ) yea...
# 3        1.0                                                 []
# 4        1.0                                                 []

# %%
debug_df_others.head()
# Out:
#                                             question  \
# 0  For STT, what is the growth rate in the risk-f...
# 1  For STT, what was the percent change in the va...
# 2  For RSG, what was the percent of the growth in...
# 3  For Citi, what was the change in tier 1 capita...
# 4  Q: what was the value of united parcel service...
#
#                                       retrieved_norm  \
# 0  [['management believes it is important for int...
# 1  [['we maintain an effective universal shelf re...
# 2  [total company revenue. the increase in organi...
# 3  [['capital resources and liquidity capital res...
# 4  [['shareowner return performance graph the fol...
#
#                                       reference_norm  \
# 0  [2006 2005 2004 dividend yield 1.41% ( 1.41 % ...
# 1  [we maintain an effective universal shelf regi...
# 2  [year ended december 31 2008 ( unaudited ) yea...
# 3  [at year end 2009 2008 tier 1 common 9.60% ( 9...
# ...

# %% [markdown]
# ## Retrieval Evaluation Metrics For FinDER

# %%
# Method 1: View a specific row by index (e.g., row 0)
row_index = 4
sample = retrieval_df_FinDER.iloc[row_index]

print(f"=== EXAMPLE {row_index} ===")
print(f"Question ID: {sample['question_id']}")
print(f"Question: {sample['user_input']}")
print(f"Source: {sample['source']}")

print(f"\n=== REFERENCE CONTEXTS ===")
for i, ref_ctx in enumerate(sample['reference_contexts']):
    print(f"Reference {i+1}:")
    print(ref_ctx)
    print("-" * 50)

print(f"\n=== RETRIEVED CONTEXTS ===")
for i, ret_ctx in enumerate(sample['retrieved_contexts']):
    print(f"Retrieved {i+1}:")
    print(ret_ctx)
    print("-" * 50)
# Out:
# === EXAMPLE 4 ===
# Question ID: 366d49d1
# Question: % of part-time workforce and flexibility in labor costs for SPG.
# Source: FinDER
#
# === REFERENCE CONTEXTS ===
# Reference 1:
# At December 31, 2023, we and our affiliates employed approximately 3,000 persons at various properties and offices throughout the United States, of which approximately 500 were part-time. Approximately 1,000 of these employees were located at our corporate headquarters in Indianapolis, Indiana.
# --------------------------------------------------
#
# === RETRIEVED CONTEXTS ===
# Retrieved 1:
# ...

# %% [markdown]
# ### Chunk Doc Substric Presence

# %%
from typing import List, Dict, Tuple
import re
import pandas as pd
from tqdm import tqdm

# %% [markdown]
# Helper Function:

# %%
_WS_RE = re.compile(r"\s+")
def normalize_text(s: str) -> str:
    if not isinstance(s, str):
        return ""
    # Lowercase, strip, collapse ALL whitespace to single spaces
    s = s.lower().strip()
    s = s.replace("\t", " ").replace("\n", " ")
    s = _WS_RE.sub(" ", s)
    return s

# %%
def string_presence_doc_substring(
    dataset: List[Dict],
    top_k_context_key: str = "retrieved_contexts",   # list[str] (ranked chunks)
    gold_context_key: str = "reference_contexts",    # list[str] (full doc text or big blocks)
    k: int = 10,
    min_chunk_chars: int = 20,                       # ignore very short retrieved snippets
    verbose: bool = False,
) -> Tuple[pd.DataFrame, pd.DataFrame]:
    """
    Exact-only evaluator (reversed):
      A retrieved chunk is relevant if its normalized text is a substring of ANY
      normalized reference context for that sample.

    Outputs:
      - recall_df: per-sample summary (hit@k, recall over gold docs as presence)
      - debug_df: per-rank boolean flags `retrieved_hit_exact` so you can reuse nDCG/MRR
    """
    recall_rows, debug_rows = [], []

    for sample in tqdm(dataset):
        question = sample.get("user_input", "N/A")
        retrieved_raw = (sample.get(top_k_context_key, []) or [])[:k]
        gold_raw = list(sample.get(gold_context_key, []) or [])

        # normalize once
        gold_norm = [normalize_text(g) for g in gold_raw]
        retrieved_norm = [normalize_text(r) for r in retrieved_raw]

        # per-retrieved: hit if retrieved_norm is a substring of any gold_norm
        retrieved_hit_exact = []
        match_into_doc_idx = []  # which reference index matched (for debugging)

        for r in retrieved_norm:
            if len(r) < min_chunk_chars:
                retrieved_hit_exact.append(False)
                match_into_doc_idx.append(None)
                continue

            hit = False
            matched_idx = None
            for gi, g in enumerate(gold_norm):
                if r and (r in g):
                    hit = True
                    matched_idx = gi
                    break
            retrieved_hit_exact.append(hit)
            match_into_doc_idx.append(matched_idx)

        # per-gold "recall": did any retrieved chunk appear inside that gold doc?
        total_gold = len(gold_norm)
        matched_doc_idxs = {idx for idx in match_into_doc_idx if idx is not None}
        recall_doc = (len(matched_doc_idxs) / total_gold) if total_gold else 0.0

        if verbose and not any(retrieved_hit_exact):
            print(f"[no-hit] {question[:80]}... (k={len(retrieved_norm)})")

        # --- summary row
        recall_rows.append({
            "question": question,
            "total_gold": total_gold,
            "retrieved_k": len(retrieved_norm),
            f"hit@{k}": 1 if any(retrieved_hit_exact) else 0,
            "recall_doc": recall_doc,
            "missing_em": [
                gold_norm[i] for i in range(total_gold) if i not in matched_doc_idxs
            ],
        })

        # --- debug row (what your nDCG/MRR use)
        debug_rows.append({
            "question": question,
            "retrieved_norm": retrieved_norm,
            "reference_norm": gold_norm,
            "retrieved_hit_exact": retrieved_hit_exact,   # <-- reuse for nDCG / MRR
            "matched_ref_index": match_into_doc_idx,      # which reference doc each rank hit
        })

    recall_df = pd.DataFrame(recall_rows)
    debug_df = pd.DataFrame(debug_rows)
    return recall_df, debug_df

# %%
recall_df_FinDER, debug_df_FinDER = string_presence_doc_substring(
    dataset=retrieval_df_FinDER.to_dict(orient="records"),
    top_k_context_key="retrieved_contexts",
    gold_context_key="reference_contexts",
    k=10,
    min_chunk_chars=20,   # raise or lower if needed
    verbose=False
)
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 1717.01it/s]

# %%
recall_df_FinDER.head()
# Out:
#                                             question  total_gold  retrieved_k  \
# 0              GM operating margin 2023 vs 2022, GM.           1           10
# 1  NGC's cyber investments boost investor confide...           1           10
# 2  SBA Comm., credit evals & DTA quality receivab...           1           10
# 3  R&D expense as a % of net product revs for VRT...           1           10
# 4  % of part-time workforce and flexibility in la...           1           10
#
#    hit@10  recall_doc                                         missing_em
# 0       1         1.0                                                 []
# 1       0         0.0  [we recognize the critical importance of maint...
# 2       0         0.0  [site leasing revenues revenue from site leasi...
# 3       0         0.0  [vertex pharmaceuticals incorporated consolida...
# 4       0         0.0  [at december 31, 2023, we and our affiliates e...

# %%
debug_df_FinDER.head()
# Out:
#                                             question  \
# 0              GM operating margin 2023 vs 2022, GM.
# 1  NGC's cyber investments boost investor confide...
# 2  SBA Comm., credit evals & DTA quality receivab...
# 3  R&D expense as a % of net product revs for VRT...
# 4  % of part-time workforce and flexibility in la...
#
#                                       retrieved_norm  \
# 0  [risk management and strategy material risks f...
# 1  [financial stability in addition to our sustai...
# 2  [exploring opportunities in evolving technolog...
# 3  [['table of contents research and development ...
# 4  [as of december 31, 2023, we had 1,681 active,...
#
#                                       reference_norm  \
# 0  [consolidated income statements (in millions, ...
# 1  [we recognize the critical importance of maint...
# 2  [site leasing revenues revenue from site leasi...
# 3  [vertex pharmaceuticals incorporated consolida...
# ...

# %% [markdown]
# ## Retrieval Evaluation Metrics for All Datasets

# %% [markdown]
# ### nDCG
# Quality of the entire ranking, with more credit for relevant items near the top, but still rewards having multiple relevant results.

# %%
def nDCG_with_reference(
    debug_df: pd.DataFrame,
    k: int = 10,
) -> pd.DataFrame:
    rows = []
    for _, row in debug_df.iterrows():
        question = row["question"]
        flags = list(row.get("retrieved_hit_exact", []) or [])[:k]

        if not flags:
            dcg = idcg = ndcg = 0.0
        else:
            dcg = sum((1 if f else 0) / log2(i + 2) for i, f in enumerate(flags))
            ideal = sorted((1 if f else 0 for f in flags), reverse=True)
            idcg = sum(rel / log2(i + 2) for i, rel in enumerate(ideal))
            ndcg = (dcg / idcg) if idcg > 0 else 0.0

        rows.append({
            "question": question,
            f"dcg@{k}": dcg,
            f"idcg@{k}": idcg,
            f"ndcg@{k}": ndcg,
        })

    ndcg_df = pd.DataFrame(rows)
    if not ndcg_df.empty:
        ndcg_df["mean_ndcg"] = ndcg_df[f"ndcg@{k}"].mean()
    return ndcg_df

# %% [markdown]
# Test on FinQA and ConvFinQA output:

# %%
ndcg_df = nDCG_with_reference(debug_df_others, k=10)

# %%
ndcg_df.head()
# Out:
#                                             question    dcg@10  idcg@10  \
# 0  For STT, what is the growth rate in the risk-f...  0.430677      1.0
# 1  For STT, what was the percent change in the va...  1.000000      1.0
# 2  For RSG, what was the percent of the growth in...  0.000000      0.0
# 3  For Citi, what was the change in tier 1 capita...  1.000000      1.0
# 4  Q: what was the value of united parcel service...  1.000000      1.0
#
#     ndcg@10  mean_ndcg
# 0  0.430677   0.686135
# 1  1.000000   0.686135
# 2  0.000000   0.686135
# 3  1.000000   0.686135
# 4  1.000000   0.686135

# %% [markdown]
# Test on FinDER output:

# %%
ndcg_df_FinDER = nDCG_with_reference(debug_df_FinDER, k=10)

# %%
ndcg_df_FinDER.head()
# Out:
#                                             question    dcg@10  idcg@10  \
# 0              GM operating margin 2023 vs 2022, GM.  0.356207      1.0
# 1  NGC's cyber investments boost investor confide...  0.000000      0.0
# 2  SBA Comm., credit evals & DTA quality receivab...  0.000000      0.0
# 3  R&D expense as a % of net product revs for VRT...  0.000000      0.0
# 4  % of part-time workforce and flexibility in la...  0.000000      0.0
#
#     ndcg@10  mean_ndcg
# 0  0.356207   0.071241
# 1  0.000000   0.071241
# 2  0.000000   0.071241
# 3  0.000000   0.071241
# 4  0.000000   0.071241

# %% [markdown]
# ### MRR
# Similar as nDCG but only considers the first retrieved item. Great for examples where the task is to retrieve one relevant context.

# %%
def MRR_with_reference(
    debug_df: pd.DataFrame,
    k: int = 10,
) -> pd.DataFrame:
    rows = []
    for _, row in debug_df.iterrows():
        question = row["question"]
        flags = list(row.get("retrieved_hit_exact", []) or [])[:k]

        if not flags:
            rr = 0.0
        else:
            try:
                # Find first True and compute reciprocal rank
                first_hit_idx = flags.index(True)  # 0-based index
                rr = 1.0 / (first_hit_idx + 1)      # rank = index + 1
            except ValueError:
                rr = 0.0  # No True found

        rows.append({
            "question": question,
            f"mrr@{k}": rr,
        })

    mrr_df = pd.DataFrame(rows)
    if not mrr_df.empty:
        mrr_df["mean_mrr"] = mrr_df[f"mrr@{k}"].mean()
    return mrr_df

# %% [markdown]
# Test on FinQA and ConvFinQA output:

# %%
mrr_df = MRR_with_reference(debug_df_others, k=10)

# %%
mrr_df.head()
# Out:
#                                             question  mrr@10  mean_mrr
# 0  For STT, what is the growth rate in the risk-f...    0.25      0.65
# 1  For STT, what was the percent change in the va...    1.00      0.65
# 2  For RSG, what was the percent of the growth in...    0.00      0.65
# 3  For Citi, what was the change in tier 1 capita...    1.00      0.65
# 4  Q: what was the value of united parcel service...    1.00      0.65

# %% [markdown]
# Test on FinDER output:

# %%
mrr_df = MRR_with_reference(debug_df_FinDER, k=10)

# %%
mrr_df.head()
# Out:
#                                             question    mrr@10  mean_mrr
# 0              GM operating margin 2023 vs 2022, GM.  0.166667  0.033333
# 1  NGC's cyber investments boost investor confide...  0.000000  0.033333
# 2  SBA Comm., credit evals & DTA quality receivab...  0.000000  0.033333
# 3  R&D expense as a % of net product revs for VRT...  0.000000  0.033333
# 4  % of part-time workforce and flexibility in la...  0.000000  0.033333

# %% [markdown]
# ### Micro Precision, Micro Recall, Micro F1
# These micro-averaged metrics evaluate retrieval performance by treating all retrieved items across all queries as one large set, rather than averaging per-query scores.<br>
# **Micro Recall**<br>
# Measures the fraction of all relevant items in the dataset that were successfully retrieved.<br>
#
# Micro Recall = Total Relevant Retrieved/ Total Relevant Items <br>
#
# ​
#
# **Micro Precision**<br>
# Measures the fraction of retrieved items that are actually relevant.<br>
# Micro Precision = Total Relevant Retrieved/ Total Retrieved Items <br>
#
# ​
#
# **Micro F1**<br>
# Harmonic mean of micro precision and micro recall, balancing both aspects.<br>
# Micro F1 = (2⋅Precision ⋅ Recall)/(Precision + Recall) <br>
#
# ​
#
# **Why micro metrics?**
# Unlike macro averaging (which computes metrics per query and then averages), micro metrics give a single overall score across the whole dataset.
# They are especially useful when:<br>
# - The number of relevant items per query is usually small, like 1.
# - You want to capture the overall retrieval success rather than per-query balance.

# %%
recall_df_others.head()
# Out:
#                                             question  total_gold  retrieved_k  \
# 0  For STT, what is the growth rate in the risk-f...           1           10
# 1  For STT, what was the percent change in the va...           2           10
# 2  For RSG, what was the percent of the growth in...           1           10
# 3  For Citi, what was the change in tier 1 capita...           1           10
# 4  Q: what was the value of united parcel service...           1           10
#
#    recall_em                                         missing_em
# 0        1.0                                                 []
# 1        1.0                                                 []
# 2        0.0  [year ended december 31 2008 ( unaudited ) yea...
# 3        1.0                                                 []
# 4        1.0                                                 []

# %%
recall_df_FinDER.head()
# Out:
#                                             question  total_gold  retrieved_k  \
# 0              GM operating margin 2023 vs 2022, GM.           1           10
# 1  NGC's cyber investments boost investor confide...           1           10
# 2  SBA Comm., credit evals & DTA quality receivab...           1           10
# 3  R&D expense as a % of net product revs for VRT...           1           10
# 4  % of part-time workforce and flexibility in la...           1           10
#
#    hit@10  recall_doc                                         missing_em
# 0       1         1.0                                                 []
# 1       0         0.0  [we recognize the critical importance of maint...
# 2       0         0.0  [site leasing revenues revenue from site leasi...
# 3       0         0.0  [vertex pharmaceuticals incorporated consolida...
# 4       0         0.0  [at december 31, 2023, we and our affiliates e...

# %%
import pandas as pd

def _ensure_columns(
    recall_df: pd.DataFrame,
    debug_df: pd.DataFrame,
    dataset_name: str,
    k: int = 10,
) -> tuple[pd.DataFrame, pd.DataFrame]:
    r = recall_df.copy()
    d = debug_df.copy()

    # tag the source
    r["dataset"] = dataset_name
    d["dataset"] = dataset_name

    # unify recall column name
    if "recall_doc" not in r.columns and "recall_em" in r.columns:
        r["recall_doc"] = r["recall_em"]
    if "recall_em" not in r.columns and "recall_doc" in r.columns:
        r["recall_em"] = r["recall_doc"]

    # make sure totals exist
    if "total_gold" not in r.columns and "total_gold_docs" in r.columns:
        r["total_gold"] = r["total_gold_docs"]

    # recompute hit@k from debug flags if missing
    if f"hit@{k}" not in r.columns:
        # align by question and compute hit from debug flags
        hits_by_q = (
            d[["question", "retrieved_hit_exact"]]
            .assign(hit=lambda x: x["retrieved_hit_exact"].apply(lambda lst: int(bool(lst and any(lst)))))
            .set_index("question")["hit"]
        )
        r = r.set_index("question")
        r[f"hit@{k}"] = r.index.map(hits_by_q).fillna(0).astype(int)
        r = r.reset_index()

    # Ensure required columns exist even if empty
    for col in ["missing_em"]:
        if col not in r.columns:
            r[col] = [[] for _ in range(len(r))]

    return r, d


def combine_eval_frames(
    recall_df_others: pd.DataFrame, debug_df_others: pd.DataFrame,
    recall_df_find: pd.DataFrame,  debug_df_find: pd.DataFrame,
    k: int = 10,
):
    r1, d1 = _ensure_columns(recall_df_others, debug_df_others, "others", k=k)
    r2, d2 = _ensure_columns(recall_df_find,   debug_df_find,   "FinDER", k=k)

    recall_df_all = pd.concat([r1, r2], ignore_index=True)
    debug_df_all  = pd.concat([d1, d2], ignore_index=True)

    # (optional) keep only the unified columns you care about
    keep_cols_recall = ["question", "dataset", "total_gold", "retrieved_k",
                        f"hit@{k}", "recall_doc", "recall_em", "missing_em"]
    recall_df_all = recall_df_all[[c for c in keep_cols_recall if c in recall_df_all.columns]]

    return recall_df_all, debug_df_all

# %%
recall_df_all, debug_df_all = combine_eval_frames(
    recall_df_others, debug_df_others,
    recall_df_FinDER, debug_df_FinDER,
    k=10
)
print(f"Combined recall_df shape: {recall_df_all.shape}")
print(f"Combined debug_df shape: {debug_df_all.shape}")
# Out:
# Combined recall_df shape: (10, 8)
# Combined debug_df shape: (10, 7)

# %%
recall_df_all.head(10)
# Out:
#                                             question dataset  total_gold  \
# 0  For STT, what is the growth rate in the risk-f...  others           1
# 1  For STT, what was the percent change in the va...  others           2
# 2  For RSG, what was the percent of the growth in...  others           1
# 3  For Citi, what was the change in tier 1 capita...  others           1
# 4  Q: what was the value of united parcel service...  others           1
# 5              GM operating margin 2023 vs 2022, GM.  FinDER           1
# 6  NGC's cyber investments boost investor confide...  FinDER           1
# 7  SBA Comm., credit evals & DTA quality receivab...  FinDER           1
# 8  R&D expense as a % of net product revs for VRT...  FinDER           1
# 9  % of part-time workforce and flexibility in la...  FinDER           1
#
#    retrieved_k  hit@10  recall_doc  recall_em  \
# 0           10       1         1.0        1.0
# 1           10       1         1.0        1.0
# ...

# %%
debug_df_all.head()
# Out:
#                                             question  \
# 0  For STT, what is the growth rate in the risk-f...
# 1  For STT, what was the percent change in the va...
# 2  For RSG, what was the percent of the growth in...
# 3  For Citi, what was the change in tier 1 capita...
# 4  Q: what was the value of united parcel service...
#
#                                       retrieved_norm  \
# 0  [['management believes it is important for int...
# 1  [['we maintain an effective universal shelf re...
# 2  [total company revenue. the increase in organi...
# 3  [['capital resources and liquidity capital res...
# 4  [['shareowner return performance graph the fol...
#
#                                       reference_norm  \
# 0  [2006 2005 2004 dividend yield 1.41% ( 1.41 % ...
# 1  [we maintain an effective universal shelf regi...
# 2  [year ended december 31 2008 ( unaudited ) yea...
# 3  [at year end 2009 2008 tier 1 common 9.60% ( 9...
# ...

# %%
def compute_micro_metrics(recall_df, recall_col="recall_doc"):
    """
    Compute micro precision, recall, and F1 from retrieval results.
    """
    if recall_df.empty:
        return {"precision_micro": 0.0, "recall_micro": 0.0, "f1_micro": 0.0}

    # Total relevant retrieved
    total_found = (recall_df[recall_col] * recall_df["total_gold"]).sum()
    
    # Total gold items
    total_gold = recall_df["total_gold"].sum()
    
    # Total retrieved
    total_retrieved = recall_df["retrieved_k"].sum()

    # Micro Recall
    recall_micro = total_found / total_gold if total_gold else 0.0

    # Micro Precision
    precision_micro = total_found / total_retrieved if total_retrieved else 0.0

    # Micro F1
    if precision_micro + recall_micro > 0:
        f1_micro = 2 * (precision_micro * recall_micro) / (precision_micro + recall_micro)
    else:
        f1_micro = 0.0

    return {
        "precision_micro": float(precision_micro),
        "recall_micro": float(recall_micro),
        "f1_micro": float(f1_micro)
    }

# %%
micro_scores = compute_micro_metrics(recall_df_all, recall_col="recall_doc")
print(micro_scores)
# Out:
# {'precision_micro': 0.06, 'recall_micro': 0.5454545454545454, 'f1_micro': 0.10810810810810809}

# %% [markdown]
# # Generator Evaluation Metrics

# %% [markdown]
# # RAG Model Evaluation

# %% [markdown]
# ## Comparision of Retrievers

# %% [markdown]
# ## Comparison of Entire Pipeline
